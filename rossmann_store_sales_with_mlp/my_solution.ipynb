# %%
# %matplotlib inline

# %%
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession
# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config))

# %%
import pandas as pd
import numpy as np
from matplotlib import pylab as plt
from pandas_summary import DataFrameSummary
import datetime

# %% [markdown]
# # Load preprocessed data

# %%
df = pd.read_feather('train_normalized_data.fth')
df_test = pd.read_feather('test_normalized_data.fth')

# %% [markdown]
# ## Show df info

# %%
print(len(df))
print(len(df.columns))
display(df.head())
display(DataFrameSummary(df).summary())
# Out:
# 844338
# 82
#    index  Store  DayOfWeek       Date  Sales  Customers  Open     Promo  \
# 0      0      0          4 2015-07-31   5263        555     1  1.273237
# 1      1      1          4 2015-07-31   6064        625     1  1.273237
# 2      2      2          4 2015-07-31   8314        821     1  1.273237
# 3      3      3          4 2015-07-31  13995       1498     1  1.273237
# 4      4      4          4 2015-07-31   4822        559     1  1.273237
#
#    StateHoliday  SchoolHoliday  ...  AfterStateHoliday_bool  \
# 0             0       2.144211  ...                0.644376
# 1             0       2.144211  ...                0.965073
# 2             0       2.144211  ...                0.644376
# 3             0       2.144211  ...                0.965073
# 4             0       2.144211  ...                0.644376
#
#    BeforeStateHoliday_bool  AfterPromo  BeforePromo  SchoolHoliday_bw  \
# 0                 1.072424           0            0                 5
# 1                 1.072424           0            0                 5
# 2                 1.072424           0            0                 5
# 3                 1.072424           0            0                 5
# 4                 1.072424           0            0                 5
#
#    StateHoliday_bool_bw  Promo_bw  SchoolHoliday_fw  StateHoliday_bool_fw  \
# 0                     0         5                 1                     0
# 1                     0         5                 1                     0
# 2                     0         5                 1                     0
# 3                     0         5                 1                     0
# 4                     0         5                 1                     0
#
#    Promo_fw
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# [5 rows x 82 columns]
# C:\Users\marco\AppData\Local\Temp\ipykernel_6168\2860104315.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   display(DataFrameSummary(df).summary())
#                      index       Store DayOfWeek    Date        Sales  \
# count             844338.0    844338.0  844338.0     NaN     844338.0
# mean          508610.35162  557.421374   2.52035     NaN  6955.959134
# std           293698.99876  321.730861  1.723712     NaN  3103.815515
# min                    0.0         0.0       0.0     NaN         46.0
# 25%              256009.25       279.0       1.0     NaN       4859.0
# 50%               510142.5       557.0       2.0     NaN       6369.0
# 75%              763017.75       836.0       4.0     NaN       8360.0
# max              1017190.0      1114.0       6.0     NaN      41551.0
# counts              844338      844338    844338  844338       844338
# uniques             844338        1115         7     942        21733
# missing                  0           0         0       0            0
# missing_perc            0%          0%        0%      0%           0%
# types              numeric     numeric   numeric    date      numeric
#
#                Customers      Open     Promo StateHoliday SchoolHoliday  ...  \
# count           844338.0  844338.0  844338.0     844338.0      844338.0  ...
# mean          762.777166       1.0  0.133484     0.001418      0.038979  ...
# std           401.194153       0.0  1.023378     0.047578      1.031446  ...
# min                  8.0       1.0   -0.7854          0.0     -0.466372  ...
# 25%                519.0       1.0   -0.7854          0.0     -0.466372  ...
# 50%                676.0       1.0   -0.7854          0.0     -0.466372  ...
# 75%                893.0       1.0  1.273237          0.0     -0.466372  ...
# max               7388.0       1.0  1.273237          3.0      2.144211  ...
# counts            844338    844338    844338       844338        844338  ...
# uniques             4083         1         2            4             2  ...
# missing                0         0         0            0             0  ...
# missing_perc          0%        0%        0%           0%            0%  ...
# types            numeric  constant      bool      numeric          bool  ...
#
#              AfterStateHoliday_bool BeforeStateHoliday_bool AfterPromo  \
# count                      844338.0                844338.0   844338.0
# mean                       0.043288               -0.035657   2.783563
# std                        0.994421                0.996632   4.913429
# min                       -1.183596               -4.861401        0.0
# 25%                       -0.830829               -0.722938        0.0
# 50%                       -0.221505                0.250818        1.0
# 75%                        0.740585                0.828985        5.0
# max                        3.145812                1.072424      188.0
# counts                       844338                  844338     844338
# uniques                         136                     147         21
# missing                           0                       0          0
# missing_perc                     0%                      0%         0%
# types                       numeric                 numeric    numeric
#
#              BeforePromo SchoolHoliday_bw StateHoliday_bool_bw  Promo_bw  \
# count           844338.0         844338.0             844338.0  844338.0
# mean           -2.869317         1.193387             0.176589  2.647116
# std             3.193761          2.01866             0.437335  1.794482
# min                -16.0              0.0                  0.0       0.0
# 25%                 -5.0              0.0                  0.0       1.0
# 50%                 -2.0              0.0                  0.0       3.0
# 75%                  0.0              2.0                  0.0       4.0
# max                  0.0              7.0                  2.0       5.0
# counts            844338           844338               844338    844338
# uniques               17                8                    3         6
# missing                0                0                    0         0
# missing_perc          0%               0%                   0%        0%
# types            numeric          numeric              numeric   numeric
#
#              SchoolHoliday_fw StateHoliday_bool_fw  Promo_fw
# count                844338.0             844338.0  844338.0
# mean                 1.184983             0.169327   2.69559
# std                  2.013705             0.430947  1.782725
# min                       0.0                  0.0       0.0
# 25%                       0.0                  0.0       1.0
# 50%                       0.0                  0.0       3.0
# 75%                       2.0                  0.0       4.0
# max                       7.0                  2.0       5.0
# counts                 844338               844338    844338
# uniques                     8                    3         6
# missing                     0                    0         0
# missing_perc               0%                   0%        0%
# types                 numeric              numeric   numeric
#
# [13 rows x 82 columns]

# %% [markdown]
# ## Categorical variables

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen', 'Promo2Weeks', 
            'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 
            'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw', 'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw']
print(len(cat_vars))
# Out:
# 22

# %% [markdown]
# ## Continuous variables

# %%
contin_vars = ['CompetitionDistance', 
   'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Promo', 'SchoolHoliday', 'StateHoliday_bool']
print(len(contin_vars))
# Out:
# 18

# %% [markdown]
# Veo valores unicos en cada variable categorica

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]
uniques.T
# Out:
#                          uniques
# Store                       1115
# DayOfWeek                      7
# Year                           3
# Month                         12
# Day                           31
# StateHoliday                   4
# CompetitionMonthsOpen         25
# Promo2Weeks                   26
# StoreType                      4
# Assortment                     3
# PromoInterval                  4
# CompetitionOpenSinceYear      21
# Promo2SinceYear                8
# State                         12
# Week                          52
# Events                        22
# Promo_fw                       6
# Promo_bw                       6
# StateHoliday_bool_fw           3
# StateHoliday_bool_bw           3
# SchoolHoliday_fw               8
# SchoolHoliday_bw               8

# %% [markdown]
# # Asignación de dimensión de embeddings

# %%
# cat_var_dict = {'Store': 5, 'DayOfWeek': 2, 'Year': 2, 'Month': 2,
# 'Day': 10, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
# 'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
# 'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
# 'Week': 25, 'Events': 4, 'Promo_fw': 1,
# 'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
# 'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
# 'SchoolHoliday_bw': 1}

# cat_var_dict = {'Store': 10, 'DayOfWeek': 6, 'Year': 2, 'Month': 6,
# 'Day': 10, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
# 'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
# 'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
# 'Week': 25, 'Events': 4, 'Promo_fw': 1,
# 'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
# 'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
# 'SchoolHoliday_bw': 1}

cat_var_dict = {'Store': 10, 'DayOfWeek': 6, 'Year': 2, 'Month': 6,
'Day': 6, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 2, 'PromoInterval': 2,
'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 2, 'State': 4,
'Week': 10, 'Events': 2, 'Promo_fw': 1,
'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
'SchoolHoliday_bw': 1}

print(len(cat_var_dict))
# Out:
# 22

# %% [markdown]
# # Definición de modelo

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras import backend as K

# %%
def get_cat_vars_model(cat_vars, uniques, cat_var_dict):
    cat_vars_embed_outs = []
    cat_var_inputs = []
    for cat_var in cat_vars:
        cat_var_in = Input(shape=(1,), name=f"{cat_var}_input")
        cat_var_inputs.append(cat_var_in)
        embed_out = Embedding(uniques[cat_var][0], cat_var_dict[cat_var], name=f'{cat_var}_Embed')(cat_var_in)
        flatten_out = Flatten(name=f"{cat_var}_flat")(embed_out)
        cat_vars_embed_outs.append(flatten_out)
    return cat_var_inputs, cat_vars_embed_outs

def get_cont_vars_input(contin_vars, dense_layer=False):
    cont_vars_inputs = []
    cont_vars_outputs = []
    for cont_var in contin_vars:
        cont_var_in = Input(shape=(1,), name=f"{cont_var}_input")
        cont_vars_inputs.append(cont_var_in)
        if dense_layer:
            cont_var_out = Dense(1, name=f"{cont_var}_input", activation = 'linear')(cont_var_in)
            cont_vars_outputs.append(cont_var_out)
        else:
            cont_vars_outputs.append(cont_var_in)
    return cont_vars_inputs, cont_vars_outputs

# %% [markdown]
# #### Defino las features a utilizar

# %%
cat_vars = ['Store', 'DayOfWeek', 'Promo_bw', 'Day', 'Month', 'Year', 'State', 'Assortment', 'StoreType', 'Events', 'StateHoliday', 'Promo2SinceYear'] #, 'PromoInterval', 'Promo2Weeks']
cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model(cat_vars, uniques, cat_var_dict)

contin_vars = [ 'Max_TemperatureC', 'Precipitationmm', 'Promo', 'SchoolHoliday', 'Max_Wind_SpeedKm_h', 'trend', 'Mean_TemperatureC'] #, 'Max_Wind_SpeedKm_h'] #, 'CompetitionDistance'] #,'BeforeStateHoliday_bool']
cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars)

# %%
first_hidden_units = 200
second_hidden_units = 200
l2_lambda = 0 #1e-4 #0.1e-3
output_activation = 'linear'

merged = Concatenate(name='All_Concatenate')(cat_vars_embed_outs + cont_vars_inputs)
x = Dense(first_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(merged)
#x = BatchNormalization()(x)
x = Activation('relu')(x)
#x = LeakyReLU()(x)
x = Dense(second_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(x)
#x = BatchNormalization()(x)
x = Activation('relu')(x)
#x = LeakyReLU()(x)

output_1 = Dense(1, name='Sales', activation=output_activation)(x)
output_2 = Dense(1, name='Customers', activation=output_activation)(x)

# %%
add_customers = True

if add_customers:
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1, output_2])
else: 
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1])
    
model.summary()
model.save_weights('initial_weights.hdf5')
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Store_input (InputLayer)       [(None, 1)]          0           []
#
#  DayOfWeek_input (InputLayer)   [(None, 1)]          0           []
#
#  Promo_bw_input (InputLayer)    [(None, 1)]          0           []
#
#  Day_input (InputLayer)         [(None, 1)]          0           []
#
#  Month_input (InputLayer)       [(None, 1)]          0           []
#
#  Year_input (InputLayer)        [(None, 1)]          0           []
#
#  State_input (InputLayer)       [(None, 1)]          0           []
#
#  Assortment_input (InputLayer)  [(None, 1)]          0           []
#
#  StoreType_input (InputLayer)   [(None, 1)]          0           []
#
#  Events_input (InputLayer)      [(None, 1)]          0           []
#
#  StateHoliday_input (InputLayer  [(None, 1)]         0           []
#  )
#
#  Promo2SinceYear_input (InputLa  [(None, 1)]         0           []
#  yer)
#
#  Store_Embed (Embedding)        (None, 1, 10)        11150       ['Store_input[0][0]']
#
#  DayOfWeek_Embed (Embedding)    (None, 1, 6)         42          ['DayOfWeek_input[0][0]']
#
#  Promo_bw_Embed (Embedding)     (None, 1, 1)         6           ['Promo_bw_input[0][0]']
#
#  Day_Embed (Embedding)          (None, 1, 6)         186         ['Day_input[0][0]']
#
#  Month_Embed (Embedding)        (None, 1, 6)         72          ['Month_input[0][0]']
#
#  Year_Embed (Embedding)         (None, 1, 2)         6           ['Year_input[0][0]']
#
#  State_Embed (Embedding)        (None, 1, 4)         48          ['State_input[0][0]']
#
#  Assortment_Embed (Embedding)   (None, 1, 2)         6           ['Assortment_input[0][0]']
#
#  StoreType_Embed (Embedding)    (None, 1, 2)         8           ['StoreType_input[0][0]']
#
#  Events_Embed (Embedding)       (None, 1, 2)         44          ['Events_input[0][0]']
#
#  StateHoliday_Embed (Embedding)  (None, 1, 2)        8           ['StateHoliday_input[0][0]']
#
#  Promo2SinceYear_Embed (Embeddi  (None, 1, 2)        16          ['Promo2SinceYear_input[0][0]']
#  ng)
#
#  Store_flat (Flatten)           (None, 10)           0           ['Store_Embed[0][0]']
#
#  DayOfWeek_flat (Flatten)       (None, 6)            0           ['DayOfWeek_Embed[0][0]']
#
#  Promo_bw_flat (Flatten)        (None, 1)            0           ['Promo_bw_Embed[0][0]']
#
#  Day_flat (Flatten)             (None, 6)            0           ['Day_Embed[0][0]']
#
#  Month_flat (Flatten)           (None, 6)            0           ['Month_Embed[0][0]']
#
#  Year_flat (Flatten)            (None, 2)            0           ['Year_Embed[0][0]']
#
#  State_flat (Flatten)           (None, 4)            0           ['State_Embed[0][0]']
#
#  Assortment_flat (Flatten)      (None, 2)            0           ['Assortment_Embed[0][0]']
#
#  StoreType_flat (Flatten)       (None, 2)            0           ['StoreType_Embed[0][0]']
#
#  Events_flat (Flatten)          (None, 2)            0           ['Events_Embed[0][0]']
#
#  StateHoliday_flat (Flatten)    (None, 2)            0           ['StateHoliday_Embed[0][0]']
#
#  Promo2SinceYear_flat (Flatten)  (None, 2)           0           ['Promo2SinceYear_Embed[0][0]']
#
#  Max_TemperatureC_input (InputL  [(None, 1)]         0           []
#  ayer)
#
#  Precipitationmm_input (InputLa  [(None, 1)]         0           []
#  yer)
#
#  Promo_input (InputLayer)       [(None, 1)]          0           []
#
#  SchoolHoliday_input (InputLaye  [(None, 1)]         0           []
#  r)
#
#  Max_Wind_SpeedKm_h_input (Inpu  [(None, 1)]         0           []
#  tLayer)
#
#  trend_input (InputLayer)       [(None, 1)]          0           []
#
#  Mean_TemperatureC_input (Input  [(None, 1)]         0           []
#  Layer)
#
#  All_Concatenate (Concatenate)  (None, 52)           0           ['Store_flat[0][0]',
#                                                                   'DayOfWeek_flat[0][0]',
#                                                                   'Promo_bw_flat[0][0]',
#                                                                   'Day_flat[0][0]',
#                                                                   'Month_flat[0][0]',
#                                                                   'Year_flat[0][0]',
#                                                                   'State_flat[0][0]',
#                                                                   'Assortment_flat[0][0]',
#                                                                   'StoreType_flat[0][0]',
#                                                                   'Events_flat[0][0]',
#                                                                   'StateHoliday_flat[0][0]',
#                                                                   'Promo2SinceYear_flat[0][0]',
#                                                                   'Max_TemperatureC_input[0][0]',
#                                                                   'Precipitationmm_input[0][0]',
#                                                                   'Promo_input[0][0]',
#                                                                   'SchoolHoliday_input[0][0]',
#                                                                   'Max_Wind_SpeedKm_h_input[0][0]'
#                                                                  , 'trend_input[0][0]',
#                                                                   'Mean_TemperatureC_input[0][0]']
#
#  dense_14 (Dense)               (None, 200)          10600       ['All_Concatenate[0][0]']
#
#  activation_14 (Activation)     (None, 200)          0           ['dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 200)          40200       ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 200)          0           ['dense_15[0][0]']
#
#  Sales (Dense)                  (None, 1)            201         ['activation_15[0][0]']
#
#  Customers (Dense)              (None, 1)            201         ['activation_15[0][0]']
#
# ==================================================================================================
# Total params: 62,794
# Trainable params: 62,794
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Separo datos en train y validation

# %%
df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]
print(f'Cantidad en val: {len(df_val)}, porcentaje: {len(df_train)/(len(df_train) + len(df_val))}')
# Out:
# Cantidad en val: 30188, porcentaje: 0.9642465458145908

# %% [markdown]
# #### Se calcula meadia de ventas por store como baseline

# %%
stores_mean = {}
for store, g_df in df_train.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()
    
df_train.loc[:, 'mean_by_store'] = df_train['Store'].apply(stores_mean.get)
df_val.loc[:, 'mean_by_store'] = df_val['Store'].apply(stores_mean.get)

df_train.loc[:, 'Sales_store'] = df_train['Sales'] - df_train['mean_by_store']
df_val.loc[:, 'Sales_store'] = df_val['Sales'] - df_val['mean_by_store']
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_6168\1524812702.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.loc[:, 'mean_by_store'] = df_train['Store'].apply(stores_mean.get)
# C:\Users\marco\AppData\Local\Temp\ipykernel_6168\1524812702.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val.loc[:, 'mean_by_store'] = df_val['Store'].apply(stores_mean.get)
# C:\Users\marco\AppData\Local\Temp\ipykernel_6168\1524812702.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.loc[:, 'Sales_store'] = df_train['Sales'] - df_train['mean_by_store']
# C:\Users\marco\AppData\Local\Temp\ipykernel_6168\1524812702.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val.loc[:, 'Sales_store'] = df_val['Sales'] - df_val['mean_by_store']

# %%
def rmspe(y_true, y_pred):
    return K.sqrt(K.mean(K.square((y_true - y_pred)/y_true)))

def get_metric(df, sales_):
    return np.sqrt((((df['Sales'] - sales_)/df['Sales'])**2).mean())

get_metric(df_val, df_val['mean_by_store'])
# Out:
# 0.3071746085338871

# %%
all_vars = cat_vars + contin_vars
X_train = np.hsplit(df_train[all_vars].values, len(all_vars))
X_val = np.hsplit(df_val[all_vars].values, len(all_vars))
X_test = np.hsplit(df_test[all_vars].values, len(all_vars))

X_full = np.hsplit(df[all_vars].values, len(all_vars))

# %%
log_output = True

if add_customers:
    y_out_columns = ['Sales', 'Customers']
else:
    y_out_columns = ['Sales'] #['Sales_store']
    
if log_output:
    # Escala logaritmica
    max_log_y = np.max(np.log(df[y_out_columns]),axis=0).values
    y_train = np.log(df_train[y_out_columns].values)/max_log_y
    y_val = np.log(df_val[y_out_columns].values)/max_log_y
    y_full = np.log(df[y_out_columns].values)/max_log_y
else:
    # Normalización
#     y_mean = df_train[y_out_columns].mean().values
#     y_std = df_train[y_out_columns].std().values
#     y_train = (df_train[y_out_columns].values - y_mean)/y_std
#     y_val = (df_val[y_out_columns].values - y_mean)/y_std
    y_max = df_train[y_out_columns].max().values
    y_train = df_train[y_out_columns].values/y_max
    y_val = df_val[y_out_columns].values/y_max
    y_full = df[y_out_columns].values/y_max

y_train = np.hsplit(y_train, y_train.shape[1])
y_val = np.hsplit(y_val, y_val.shape[1])
y_full = np.hsplit(y_full, y_full.shape[1])

# %%
lr = 0.001
model.compile(optimizer=Adam(learning_rate=lr), metrics=['mse', rmspe], loss='mse')

if add_customers:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_Sales_mse', verbose=1, save_best_only=True)
else:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
epochs = 8 #20
batch_size = 256
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),  epochs=epochs, batch_size=batch_size, callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/8
#
# Epoch 1: val_Sales_mse improved from inf to 0.00022, saving model to bestmodel.hdf5
# 3181/3181 - 28s - loss: 0.0035 - Sales_loss: 0.0019 - Customers_loss: 0.0017 - Sales_mse: 0.0019 - Sales_rmspe: 0.0258 - Customers_mse: 0.0017 - Customers_rmspe: 0.0300 - val_loss: 4.3410e-04 - val_Sales_loss: 2.2115e-04 - val_Customers_loss: 2.1295e-04 - val_Sales_mse: 2.2115e-04 - val_Sales_rmspe: 0.0177 - val_Customers_mse: 2.1295e-04 - val_Customers_rmspe: 0.0197 - 28s/epoch - 9ms/step
# Epoch 2/8
#
# Epoch 2: val_Sales_mse did not improve from 0.00022
# 3181/3181 - 29s - loss: 3.2741e-04 - Sales_loss: 1.6003e-04 - Customers_loss: 1.6739e-04 - Sales_mse: 1.6003e-04 - Sales_rmspe: 0.0155 - Customers_mse: 1.6739e-04 - Customers_rmspe: 0.0180 - val_loss: 3.9915e-04 - val_Sales_loss: 2.3621e-04 - val_Customers_loss: 1.6294e-04 - val_Sales_mse: 2.3621e-04 - val_Sales_rmspe: 0.0182 - val_Customers_mse: 1.6294e-04 - val_Customers_rmspe: 0.0174 - 29s/epoch - 9ms/step
# Epoch 3/8
#
# Epoch 3: val_Sales_mse improved from 0.00022 to 0.00015, saving model to bestmodel.hdf5
# 3181/3181 - 28s - loss: 2.7737e-04 - Sales_loss: 1.3721e-04 - Customers_loss: 1.4017e-04 - Sales_mse: 1.3721e-04 - Sales_rmspe: 0.0144 - Customers_mse: 1.4017e-04 - Customers_rmspe: 0.0165 - val_loss: 3.0210e-04 - val_Sales_loss: 1.5423e-04 - val_Customers_loss: 1.4787e-04 - val_Sales_mse: 1.5423e-04 - val_Sales_rmspe: 0.0148 - val_Customers_mse: 1.4787e-04 - val_Customers_rmspe: 0.0165 - 28s/epoch - 9ms/step
# Epoch 4/8
#
# Epoch 4: val_Sales_mse improved from 0.00015 to 0.00014, saving model to bestmodel.hdf5
# 3181/3181 - 26s - loss: 2.4613e-04 - Sales_loss: 1.2197e-04 - Customers_loss: 1.2416e-04 - Sales_mse: 1.2197e-04 - Sales_rmspe: 0.0136 - Customers_mse: 1.2416e-04 - Customers_rmspe: 0.0155 - val_loss: 2.8811e-04 - val_Sales_loss: 1.4165e-04 - val_Customers_loss: 1.4646e-04 - val_Sales_mse: 1.4165e-04 - val_Sales_rmspe: 0.0143 - val_Customers_mse: 1.4646e-04 - val_Customers_rmspe: 0.0164 - 26s/epoch - 8ms/step
# Epoch 5/8
#
# Epoch 5: val_Sales_mse improved from 0.00014 to 0.00013, saving model to bestmodel.hdf5
# 3181/3181 - 25s - loss: 2.2241e-04 - Sales_loss: 1.1086e-04 - Customers_loss: 1.1155e-04 - Sales_mse: 1.1086e-04 - Sales_rmspe: 0.0129 - Customers_mse: 1.1155e-04 - Customers_rmspe: 0.0147 - val_loss: 2.4940e-04 - val_Sales_loss: 1.2644e-04 - val_Customers_loss: 1.2296e-04 - val_Sales_mse: 1.2644e-04 - val_Sales_rmspe: 0.0136 - val_Customers_mse: 1.2296e-04 - val_Customers_rmspe: 0.0151 - 25s/epoch - 8ms/step
# Epoch 6/8
#
# Epoch 6: val_Sales_mse improved from 0.00013 to 0.00012, saving model to bestmodel.hdf5
# 3181/3181 - 25s - loss: 2.0525e-04 - Sales_loss: 1.0257e-04 - Customers_loss: 1.0268e-04 - Sales_mse: 1.0257e-04 - Sales_rmspe: 0.0125 - Customers_mse: 1.0268e-04 - Customers_rmspe: 0.0142 - val_loss: 2.4299e-04 - val_Sales_loss: 1.1856e-04 - val_Customers_loss: 1.2443e-04 - val_Sales_mse: 1.1856e-04 - val_Sales_rmspe: 0.0131 - val_Customers_mse: 1.2443e-04 - val_Customers_rmspe: 0.0152 - 25s/epoch - 8ms/step
# Epoch 7/8
#
# Epoch 7: val_Sales_mse improved from 0.00012 to 0.00011, saving model to bestmodel.hdf5
# 3181/3181 - 25s - loss: 1.9230e-04 - Sales_loss: 9.6511e-05 - Customers_loss: 9.5793e-05 - Sales_mse: 9.6511e-05 - Sales_rmspe: 0.0121 - Customers_mse: 9.5793e-05 - Customers_rmspe: 0.0137 - val_loss: 2.2955e-04 - val_Sales_loss: 1.0801e-04 - val_Customers_loss: 1.2154e-04 - val_Sales_mse: 1.0801e-04 - val_Sales_rmspe: 0.0126 - val_Customers_mse: 1.2154e-04 - val_Customers_rmspe: 0.0149 - 25s/epoch - 8ms/step
# Epoch 8/8
#
# Epoch 8: val_Sales_mse did not improve from 0.00011
# 3181/3181 - 25s - loss: 1.8374e-04 - Sales_loss: 9.2674e-05 - Customers_loss: 9.1065e-05 - Sales_mse: 9.2674e-05 - Sales_rmspe: 0.0118 - Customers_mse: 9.1065e-05 - Customers_rmspe: 0.0133 - val_loss: 2.6353e-04 - val_Sales_loss: 1.3019e-04 - val_Customers_loss: 1.3334e-04 - val_Sales_mse: 1.3019e-04 - val_Sales_rmspe: 0.0137 - val_Customers_mse: 1.3334e-04 - val_Customers_rmspe: 0.0157 - 25s/epoch - 8ms/step

# %%
model.load_weights('bestmodel.hdf5')

# %%
plt.figure()

if not add_customers:
    plt.plot(history.history['loss'],label='train_loss')
    plt.plot(history.history['val_loss'],label='val_loss')
    plt.legend()
    plt.grid()

    plt.figure()
    plt.plot(history.history['mse'],label='train_sales_mse')
    plt.plot(history.history['val_mse'],label='val_sales_mse')
    plt.legend()
    plt.grid()
else:
    plt.plot(history.history['val_Customers_mse'][1:],label='val_customers_mse')
    plt.plot(history.history['val_Sales_mse'][1:],label='val_sales_mse')
    plt.plot(history.history['Customers_mse'][1:],label='train_customers_mse')
    plt.plot(history.history['Sales_mse'][1:],label='train_sales_mse')
    plt.legend()
    plt.grid()
plt.show()

# %%
#model.evaluate(X_train, y_train)

# %%
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 5s 5ms/step - loss: 2.2955e-04 - Sales_loss: 1.0801e-04 - Customers_loss: 1.2154e-04 - Sales_mse: 1.0801e-04 - Sales_rmspe: 0.0124 - Customers_mse: 1.2154e-04 - Customers_rmspe: 0.0147
# [0.00022955110762268305,
#  0.000108009968244005,
#  0.00012154127034591511,
#  0.000108009968244005,
#  0.012354524806141853,
#  0.00012154127034591511,
#  0.014682896435260773]

# %% [markdown]
# # Final train with full dataset

# %%
epochs = 8 #20
batch_size = 256
history = model.fit(X_full, y_full, validation_data=(X_val, y_val),  epochs=epochs, batch_size=batch_size, callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/8
#
# Epoch 1: val_Sales_mse improved from 0.00011 to 0.00009, saving model to bestmodel.hdf5
# 3299/3299 - 29s - loss: 1.8473e-04 - Sales_loss: 9.3154e-05 - Customers_loss: 9.1576e-05 - Sales_mse: 9.3154e-05 - Sales_rmspe: 0.0119 - Customers_mse: 9.1576e-05 - Customers_rmspe: 0.0134 - val_loss: 1.6917e-04 - val_Sales_loss: 8.7729e-05 - val_Customers_loss: 8.1442e-05 - val_Sales_mse: 8.7729e-05 - val_Sales_rmspe: 0.0114 - val_Customers_mse: 8.1442e-05 - val_Customers_rmspe: 0.0124 - 29s/epoch - 9ms/step
# Epoch 2/8
#
# Epoch 2: val_Sales_mse improved from 0.00009 to 0.00009, saving model to bestmodel.hdf5
# 3299/3299 - 27s - loss: 1.7636e-04 - Sales_loss: 8.9225e-05 - Customers_loss: 8.7139e-05 - Sales_mse: 8.9225e-05 - Sales_rmspe: 0.0116 - Customers_mse: 8.7139e-05 - Customers_rmspe: 0.0130 - val_loss: 1.6590e-04 - val_Sales_loss: 8.5749e-05 - val_Customers_loss: 8.0153e-05 - val_Sales_mse: 8.5749e-05 - val_Sales_rmspe: 0.0113 - val_Customers_mse: 8.0153e-05 - val_Customers_rmspe: 0.0123 - 27s/epoch - 8ms/step
# Epoch 3/8
#
# Epoch 3: val_Sales_mse did not improve from 0.00009
# 3299/3299 - 29s - loss: 1.7079e-04 - Sales_loss: 8.6731e-05 - Customers_loss: 8.4057e-05 - Sales_mse: 8.6731e-05 - Sales_rmspe: 0.0114 - Customers_mse: 8.4057e-05 - Customers_rmspe: 0.0128 - val_loss: 1.9928e-04 - val_Sales_loss: 1.0541e-04 - val_Customers_loss: 9.3869e-05 - val_Sales_mse: 1.0541e-04 - val_Sales_rmspe: 0.0123 - val_Customers_mse: 9.3869e-05 - val_Customers_rmspe: 0.0132 - 29s/epoch - 9ms/step
# Epoch 4/8
#
# Epoch 4: val_Sales_mse did not improve from 0.00009
# 3299/3299 - 36s - loss: 1.6656e-04 - Sales_loss: 8.4775e-05 - Customers_loss: 8.1787e-05 - Sales_mse: 8.4775e-05 - Sales_rmspe: 0.0113 - Customers_mse: 8.1787e-05 - Customers_rmspe: 0.0126 - val_loss: 1.6230e-04 - val_Sales_loss: 8.7273e-05 - val_Customers_loss: 7.5022e-05 - val_Sales_mse: 8.7273e-05 - val_Sales_rmspe: 0.0114 - val_Customers_mse: 7.5022e-05 - val_Customers_rmspe: 0.0119 - 36s/epoch - 11ms/step
# Epoch 5/8
#
# Epoch 5: val_Sales_mse did not improve from 0.00009
# 3299/3299 - 31s - loss: 1.6326e-04 - Sales_loss: 8.3258e-05 - Customers_loss: 8.0006e-05 - Sales_mse: 8.3258e-05 - Sales_rmspe: 0.0112 - Customers_mse: 8.0006e-05 - Customers_rmspe: 0.0125 - val_loss: 1.6965e-04 - val_Sales_loss: 9.1378e-05 - val_Customers_loss: 7.8269e-05 - val_Sales_mse: 9.1378e-05 - val_Sales_rmspe: 0.0117 - val_Customers_mse: 7.8269e-05 - val_Customers_rmspe: 0.0122 - 31s/epoch - 9ms/step
# Epoch 6/8
#
# Epoch 6: val_Sales_mse improved from 0.00009 to 0.00008, saving model to bestmodel.hdf5
# 3299/3299 - 30s - loss: 1.6031e-04 - Sales_loss: 8.1746e-05 - Customers_loss: 7.8561e-05 - Sales_mse: 8.1746e-05 - Sales_rmspe: 0.0111 - Customers_mse: 7.8561e-05 - Customers_rmspe: 0.0124 - val_loss: 1.5686e-04 - val_Sales_loss: 7.7019e-05 - val_Customers_loss: 7.9840e-05 - val_Sales_mse: 7.7019e-05 - val_Sales_rmspe: 0.0107 - val_Customers_mse: 7.9840e-05 - val_Customers_rmspe: 0.0124 - 30s/epoch - 9ms/step
# Epoch 7/8
#
# Epoch 7: val_Sales_mse did not improve from 0.00008
# 3299/3299 - 32s - loss: 1.5821e-04 - Sales_loss: 8.0834e-05 - Customers_loss: 7.7380e-05 - Sales_mse: 8.0834e-05 - Sales_rmspe: 0.0110 - Customers_mse: 7.7380e-05 - Customers_rmspe: 0.0123 - val_loss: 1.5434e-04 - val_Sales_loss: 8.2013e-05 - val_Customers_loss: 7.2328e-05 - val_Sales_mse: 8.2013e-05 - val_Sales_rmspe: 0.0109 - val_Customers_mse: 7.2328e-05 - val_Customers_rmspe: 0.0116 - 32s/epoch - 10ms/step
# Epoch 8/8
#
# Epoch 8: val_Sales_mse did not improve from 0.00008
# 3299/3299 - 31s - loss: 1.5717e-04 - Sales_loss: 8.0417e-05 - Customers_loss: 7.6751e-05 - Sales_mse: 8.0417e-05 - Sales_rmspe: 0.0110 - Customers_mse: 7.6751e-05 - Customers_rmspe: 0.0122 - val_loss: 1.5134e-04 - val_Sales_loss: 7.9611e-05 - val_Customers_loss: 7.1729e-05 - val_Sales_mse: 7.9611e-05 - val_Sales_rmspe: 0.0109 - val_Customers_mse: 7.1729e-05 - val_Customers_rmspe: 0.0117 - 31s/epoch - 9ms/step

# %%
model.load_weights('bestmodel.hdf5')

# %%
plt.figure()

if not add_customers:
    plt.plot(history.history['loss'],label='train_loss')
    plt.plot(history.history['val_loss'],label='val_loss')
    plt.legend()
    plt.grid()

    plt.figure()
    plt.plot(history.history['mse'],label='train_sales_mse')
    plt.plot(history.history['val_mse'],label='val_sales_mse')
    plt.legend()
    plt.grid()
else:
    plt.plot(history.history['val_Customers_mse'][1:],label='val_customers_mse')
    plt.plot(history.history['val_Sales_mse'][1:],label='val_sales_mse')
    plt.plot(history.history['Customers_mse'][1:],label='train_customers_mse')
    plt.plot(history.history['Sales_mse'][1:],label='train_sales_mse')
    plt.legend()
    plt.grid()
plt.show()

# %%
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 6s 6ms/step - loss: 1.5686e-04 - Sales_loss: 7.7019e-05 - Customers_loss: 7.9840e-05 - Sales_mse: 7.7019e-05 - Sales_rmspe: 0.0105 - Customers_mse: 7.9840e-05 - Customers_rmspe: 0.0121
# [0.00015685916878283024,
#  7.701909635215998e-05,
#  7.984010153450072e-05,
#  7.701909635215998e-05,
#  0.010486355051398277,
#  7.984010153450072e-05,
#  0.012143914587795734]

# %% [markdown]
# # Test predictions to submit

# %%
if log_output:
    # Escala logaritmica
    test_predictions = np.exp(model.predict(X_test)*max_log_y)
else:
    test_predictions = model.predict(X_test)*y_max
test_predictions[df_test['Open'] == 0] = 0
# Out:
# 1284/1284 [==============================] - 4s 3ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [146], line 6
#       4 else:
#       5     test_predictions = model.predict(X_test)*y_max
# ----> 6 test_predictions[df_test['Open'] == 0] = 0
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 2 but corresponding boolean dimension is 41088

# %%
sample_csv = pd.read_csv('dataset/rossmann/sample_submission.csv')
if add_customers:
    sample_csv['Sales'] = test_predictions[0]
else:
    sample_csv['Sales'] = test_predictions
sample_csv.head()

#sample_csv.to_csv(f'submision_nineth_mlp_logout_{"-".join(cat_vars)}_{"-".join(contin_vars)}.csv', index=False)
sample_csv.to_csv(f'submision_sixteenth_allds_mlp_logout.csv', index=False)
