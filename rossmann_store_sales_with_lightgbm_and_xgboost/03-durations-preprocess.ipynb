# %%
import pandas as pd
import numpy as np

# %%
joined_train = pd.read_feather('joined_train_before_durations.fth')
joined_test = pd.read_feather('joined_test_before_durations.fth')

# %% [markdown]
# # Paso StateHoliday a booleana

# %%
joined_train['StateHoliday'].value_counts()
# Out:
# 0    986159
# a     20260
# b      6690
# c      4100
# Name: StateHoliday, dtype: int64

# %% [markdown]
# a = public holiday, b = Easter holiday, c = Christmas, 0 = None

# %%
joined_train['StateHoliday_bool'] = joined_train.StateHoliday!='0'
joined_test['StateHoliday_bool'] = joined_test.StateHoliday!='0'

# %% [markdown]
# ## Durations

# %% [markdown]
# ### Agrega columnas con "antes" y "despues" de eventos

# %%
columns = ["Date", "Store", "Promo", "StateHoliday_bool", "SchoolHoliday"]

# %%
class elapsed(object):
    def __init__(self, fld):
        self.fld = fld
        self.last = pd.to_datetime(np.nan)
        self.last_store = 0
        
    def get(self, row):
        if row.Store != self.last_store:
            self.last = pd.to_datetime(np.nan)
            self.last_store = row.Store
        if (row[self.fld]): self.last = row.Date
        return row.Date-self.last

# %%
df_train = joined_train[columns]
df_test = joined_test[columns]

# %%
df_train.head()
# Out:
#         Date  Store  Promo  StateHoliday_bool  SchoolHoliday
# 0 2015-07-31      1      1              False              1
# 1 2015-07-31      2      1              False              1
# 2 2015-07-31      3      1              False              1
# 3 2015-07-31      4      1              False              1
# 4 2015-07-31      5      1              False              1

# %%
df_test.head()
# Out:
#         Date  Store  Promo  StateHoliday_bool  SchoolHoliday
# 0 2015-09-17      1      1              False              0
# 1 2015-09-17      3      1              False              0
# 2 2015-09-17      7      1              False              0
# 3 2015-09-17      8      1              False              0
# 4 2015-09-17      9      1              False              0

# %%
def add_elapsed(df, fld, prefix):
    sh_el = elapsed(fld)
    df[prefix+fld] = df.apply(sh_el.get, axis=1)

# %%
fld = 'SchoolHoliday'
df_train = df_train.sort_values(['Store', 'Date'])
add_elapsed(df_train, fld, 'After')
df_train.head()
# Out:
#               Date  Store  Promo  StateHoliday_bool  SchoolHoliday  \
# 1016095 2013-01-01      1      0               True              1
# 1014980 2013-01-02      1      0              False              1
# 1013865 2013-01-03      1      0              False              1
# 1012750 2013-01-04      1      0              False              1
# 1011635 2013-01-05      1      0              False              1
#
#         AfterSchoolHoliday
# 1016095             0 days
# 1014980             0 days
# 1013865             0 days
# 1012750             0 days
# 1011635             0 days

# %%
df_test = df_test.sort_values(['Store', 'Date'])
add_elapsed(df_test, fld, 'After')
df_test.head()
# Out:
#             Date  Store  Promo  StateHoliday_bool  SchoolHoliday  \
# 40232 2015-08-01      1      0              False              1
# 39376 2015-08-02      1      0              False              1
# 38520 2015-08-03      1      1              False              1
# 37664 2015-08-04      1      1              False              1
# 36808 2015-08-05      1      1              False              1
#
#       AfterSchoolHoliday
# 40232             0 days
# 39376             0 days
# 38520             0 days
# 37664             0 days
# 36808             0 days

# %%
df_train = df_train.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df_train, fld, 'Before')
df_train.head()
# Out:
#            Date  Store  Promo  StateHoliday_bool  SchoolHoliday  \
# 0    2015-07-31      1      1              False              1
# 1115 2015-07-30      1      1              False              1
# 2230 2015-07-29      1      1              False              1
# 3345 2015-07-28      1      1              False              1
# 4460 2015-07-27      1      1              False              1
#
#      AfterSchoolHoliday BeforeSchoolHoliday
# 0                0 days              0 days
# 1115             0 days              0 days
# 2230             0 days              0 days
# 3345             0 days              0 days
# 4460             0 days              0 days

# %%
df_test = df_test.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df_test, fld, 'Before')
df_test.head()
# Out:
#            Date  Store  Promo  StateHoliday_bool  SchoolHoliday  \
# 0    2015-09-17      1      1              False              0
# 856  2015-09-16      1      1              False              0
# 1712 2015-09-15      1      1              False              0
# 2568 2015-09-14      1      1              False              0
# 3424 2015-09-13      1      0              False              0
#
#      AfterSchoolHoliday BeforeSchoolHoliday
# 0               13 days                 NaT
# 856             12 days                 NaT
# 1712            11 days                 NaT
# 2568            10 days                 NaT
# 3424             9 days                 NaT

# %%
fld = 'StateHoliday_bool'
df_train = df_train.sort_values(['Store', 'Date'])
add_elapsed(df_train, fld, 'After')
df_train = df_train.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df_train, fld, 'Before')

# %%
fld = 'StateHoliday_bool'
df_test = df_test.sort_values(['Store', 'Date'])
add_elapsed(df_test, fld, 'After')
df_test = df_test.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df_test, fld, 'Before')

# %%
fld = 'Promo'
df_train = df_train.sort_values(['Store', 'Date'])
add_elapsed(df_train, fld, 'After')
df_train = df_train.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df_train, fld, 'Before')

# %%
fld = 'Promo'
df_test = df_test.sort_values(['Store', 'Date'])
add_elapsed(df_test, fld, 'After')
df_test = df_test.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df_test, fld, 'Before')

# %%
df_train.head(10)
# Out:
#             Date  Store  Promo  StateHoliday_bool  SchoolHoliday  \
# 0     2015-07-31      1      1              False              1
# 1115  2015-07-30      1      1              False              1
# 2230  2015-07-29      1      1              False              1
# 3345  2015-07-28      1      1              False              1
# 4460  2015-07-27      1      1              False              1
# 5575  2015-07-26      1      0              False              0
# 6690  2015-07-25      1      0              False              0
# 7805  2015-07-24      1      0              False              0
# 8920  2015-07-23      1      0              False              0
# 10035 2015-07-22      1      0              False              0
#
#       AfterSchoolHoliday BeforeSchoolHoliday AfterStateHoliday_bool  \
# 0                 0 days              0 days                57 days
# 1115              0 days              0 days                56 days
# 2230              0 days              0 days                55 days
# 3345              0 days              0 days                54 days
# 4460              0 days              0 days                53 days
# 5575            107 days             -1 days                52 days
# 6690            106 days             -2 days                51 days
# 7805            105 days             -3 days                50 days
# 8920            104 days             -4 days                49 days
# 10035           103 days             -5 days                48 days
#
#       BeforeStateHoliday_bool AfterPromo BeforePromo
# 0                         NaT     0 days      0 days
# 1115                      NaT     0 days      0 days
# 2230                      NaT     0 days      0 days
# 3345                      NaT     0 days      0 days
# 4460                      NaT     0 days      0 days
# 5575                      NaT     9 days     -1 days
# 6690                      NaT     8 days     -2 days
# 7805                      NaT     7 days     -3 days
# 8920                      NaT     6 days     -4 days
# 10035                     NaT     5 days     -5 days

# %%
df_train = df_train.set_index("Date")
df_test = df_test.set_index("Date")

# %%
df_train.sort_values('Date').head(5)
# Out:
#             Store  Promo  StateHoliday_bool  SchoolHoliday AfterSchoolHoliday  \
# Date
# 2013-01-01   1115      0               True              1             0 days
# 2013-01-01    746      0               True              1             0 days
# 2013-01-01    171      0               True              1             0 days
# 2013-01-01    694      0               True              1             0 days
# 2013-01-01    396      0               True              1             0 days
#
#            BeforeSchoolHoliday AfterStateHoliday_bool BeforeStateHoliday_bool  \
# Date
# 2013-01-01              0 days                 0 days                  0 days
# 2013-01-01              0 days                 0 days                  0 days
# 2013-01-01              0 days                 0 days                  0 days
# 2013-01-01              0 days                 0 days                  0 days
# 2013-01-01              0 days                 0 days                  0 days
#
#            AfterPromo BeforePromo
# Date
# 2013-01-01        NaT     -6 days
# 2013-01-01        NaT     -6 days
# 2013-01-01        NaT     -6 days
# 2013-01-01        NaT     -6 days
# 2013-01-01        NaT     -6 days

# %% [markdown]
# NaT: Not a Time

# %%
df_test.sort_values('Date').head(5)
# Out:
#             Store  Promo  StateHoliday_bool  SchoolHoliday AfterSchoolHoliday  \
# Date
# 2015-08-01    553      0              False              0                NaT
# 2015-08-01    394      0              False              1             0 days
# 2015-08-01    393      0              False              0                NaT
# 2015-08-01    392      0              False              0                NaT
# 2015-08-01    391      0              False              0                NaT
#
#            BeforeSchoolHoliday AfterStateHoliday_bool BeforeStateHoliday_bool  \
# Date
# 2015-08-01             -2 days                    NaT                     NaT
# 2015-08-01              0 days                    NaT                     NaT
# 2015-08-01             -2 days                    NaT                     NaT
# 2015-08-01             -2 days                    NaT                     NaT
# 2015-08-01             -2 days                    NaT                     NaT
#
#            AfterPromo BeforePromo
# Date
# 2015-08-01        NaT     -2 days
# 2015-08-01        NaT     -2 days
# 2015-08-01        NaT     -2 days
# 2015-08-01        NaT     -2 days
# 2015-08-01        NaT     -2 days

# %% [markdown]
# ### Elimina los NaT

# %%
columns = ['SchoolHoliday', 'StateHoliday_bool', 'Promo']

# %%
for o in ['Before', 'After']:
    for p in columns:
        a = o+p
        df_train[a] = df_train[a].fillna(pd.Timedelta(0)).dt.days
        df_test[a] = df_test[a].fillna(pd.Timedelta(0)).dt.days

# %%
df_train.sort_values('Date').head(10)
# Out:
#             Store  Promo  StateHoliday_bool  SchoolHoliday  \
# Date
# 2013-01-01   1115      0               True              1
# 2013-01-01    746      0               True              1
# 2013-01-01    171      0               True              1
# 2013-01-01    694      0               True              1
# 2013-01-01    396      0               True              1
# 2013-01-01    196      0               True              1
# 2013-01-01    271      0               True              1
# 2013-01-01     32      0               True              1
# 2013-01-01    440      0               True              1
# 2013-01-01   1090      0               True              1
#
#             AfterSchoolHoliday  BeforeSchoolHoliday  AfterStateHoliday_bool  \
# Date
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
# 2013-01-01                   0                    0                       0
#
#             BeforeStateHoliday_bool  AfterPromo  BeforePromo
# Date
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6
# 2013-01-01                        0           0           -6

# %%
df_test.sort_values('Date').head(10)
# Out:
#             Store  Promo  StateHoliday_bool  SchoolHoliday  \
# Date
# 2015-08-01    553      0              False              0
# 2015-08-01    394      0              False              1
# 2015-08-01    393      0              False              0
# 2015-08-01    392      0              False              0
# 2015-08-01    391      0              False              0
# 2015-08-01    389      0              False              0
# 2015-08-01    388      0              False              0
# 2015-08-01    387      0              False              0
# 2015-08-01    386      0              False              0
# 2015-08-01    385      0              False              0
#
#             AfterSchoolHoliday  BeforeSchoolHoliday  AfterStateHoliday_bool  \
# Date
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                    0                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
# 2015-08-01                   0                   -2                       0
#
#             BeforeStateHoliday_bool  AfterPromo  BeforePromo
# Date
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                        0           0           -2
# 2015-08-01                      -14           0           -2

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(20,3))
df_train[df_train['Store'] == 280]['BeforeSchoolHoliday'].plot()
df_train[df_train['Store'] == 280]['BeforeStateHoliday_bool'].plot()
df_train[df_train['Store'] == 280]['BeforePromo'].plot()
plt.legend()
plt.show()

plt.figure(figsize=(20,3))
df_train[df_train['Store'] == 280]['AfterSchoolHoliday'].plot()
df_train[df_train['Store'] == 280]['AfterStateHoliday_bool'].plot()
df_train[df_train['Store'] == 280]['AfterPromo'].plot()
plt.legend()
plt.show()

# %% [markdown]
# ### "Suavizado" de columnas temporales

# %%
# Datos del store 1 ordenados por fecha
df_train[df_train[['Store']+columns]['Store'] == 1].sort_values('Date').head(20)
# Out:
#             Store  Promo  StateHoliday_bool  SchoolHoliday  \
# Date
# 2013-01-01      1      0               True              1
# 2013-01-02      1      0              False              1
# 2013-01-03      1      0              False              1
# 2013-01-04      1      0              False              1
# 2013-01-05      1      0              False              1
# 2013-01-06      1      0              False              1
# 2013-01-07      1      1              False              1
# 2013-01-08      1      1              False              1
# 2013-01-09      1      1              False              1
# 2013-01-10      1      1              False              1
# 2013-01-11      1      1              False              1
# 2013-01-12      1      0              False              0
# 2013-01-13      1      0              False              0
# 2013-01-14      1      0              False              0
# 2013-01-15      1      0              False              0
# 2013-01-16      1      0              False              0
# 2013-01-17      1      0              False              0
# 2013-01-18      1      0              False              0
# 2013-01-19      1      0              False              0
# 2013-01-20      1      0              False              0
#
#             AfterSchoolHoliday  BeforeSchoolHoliday  AfterStateHoliday_bool  \
# Date
# 2013-01-01                   0                    0                       0
# 2013-01-02                   0                    0                       1
# 2013-01-03                   0                    0                       2
# 2013-01-04                   0                    0                       3
# 2013-01-05                   0                    0                       4
# 2013-01-06                   0                    0                       5
# 2013-01-07                   0                    0                       6
# 2013-01-08                   0                    0                       7
# 2013-01-09                   0                    0                       8
# 2013-01-10                   0                    0                       9
# 2013-01-11                   0                    0                      10
# 2013-01-12                   1                  -72                      11
# 2013-01-13                   2                  -71                      12
# 2013-01-14                   3                  -70                      13
# 2013-01-15                   4                  -69                      14
# 2013-01-16                   5                  -68                      15
# 2013-01-17                   6                  -67                      16
# 2013-01-18                   7                  -66                      17
# 2013-01-19                   8                  -65                      18
# 2013-01-20                   9                  -64                      19
#
#             BeforeStateHoliday_bool  AfterPromo  BeforePromo
# Date
# 2013-01-01                        0           0           -6
# 2013-01-02                      -86           0           -5
# 2013-01-03                      -85           0           -4
# 2013-01-04                      -84           0           -3
# 2013-01-05                      -83           0           -2
# 2013-01-06                      -82           0           -1
# 2013-01-07                      -81           0            0
# 2013-01-08                      -80           0            0
# 2013-01-09                      -79           0            0
# 2013-01-10                      -78           0            0
# 2013-01-11                      -77           0            0
# 2013-01-12                      -76           1           -9
# 2013-01-13                      -75           2           -8
# 2013-01-14                      -74           3           -7
# 2013-01-15                      -73           4           -6
# 2013-01-16                      -72           5           -5
# 2013-01-17                      -71           6           -4
# 2013-01-18                      -70           7           -3
# 2013-01-19                      -69           8           -2
# 2013-01-20                      -68           9           -1

# %%
bwd_train = df_train[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum()
bwd_test = df_test[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum()
bwd_train.head(20)
# Out:
#                   SchoolHoliday  StateHoliday_bool  Promo
# Store Date
# 1     2013-01-01            1.0                1.0    0.0
#       2013-01-02            2.0                1.0    0.0
#       2013-01-03            3.0                1.0    0.0
#       2013-01-04            4.0                1.0    0.0
#       2013-01-05            5.0                1.0    0.0
#       2013-01-06            6.0                1.0    0.0
#       2013-01-07            7.0                1.0    1.0
#       2013-01-08            7.0                0.0    2.0
#       2013-01-09            7.0                0.0    3.0
#       2013-01-10            7.0                0.0    4.0
#       2013-01-11            7.0                0.0    5.0
#       2013-01-12            6.0                0.0    5.0
#       2013-01-13            5.0                0.0    5.0
#       2013-01-14            4.0                0.0    4.0
#       2013-01-15            3.0                0.0    3.0
#       2013-01-16            2.0                0.0    2.0
#       2013-01-17            1.0                0.0    1.0
#       2013-01-18            0.0                0.0    0.0
#       2013-01-19            0.0                0.0    0.0
#       2013-01-20            0.0                0.0    0.0

# %%
bwd_train.drop('Store',1,inplace=True)
bwd_train.reset_index(inplace=True)
bwd_test.drop('Store',1,inplace=True)
bwd_test.reset_index(inplace=True)
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_17344\2087890070.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   bwd_train.drop('Store',0,inplace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Store'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 bwd_train.drop('Store',0,inplace=True)
#       2 bwd_train.reset_index(inplace=True)
#       3 bwd_test.drop('Store',0,inplace=True)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\multi.py:2234, in MultiIndex.drop(self, codes, level, errors)
#    2232 for level_codes in codes:
#    2233     try:
# -> 2234         loc = self.get_loc(level_codes)
#    2235         # get_loc returns either an integer, a slice, or a boolean
#    2236         # mask
#    2237         if isinstance(loc, int):
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\multi.py:2869, in MultiIndex.get_loc(self, key, method)
#    2866     return mask
#    2868 if not isinstance(key, tuple):
# -> 2869     loc = self._get_level_indexer(key, level=0)
#    2870     return _maybe_to_slice(loc)
#    2872 keylen = len(key)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\multi.py:3222, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3218         return slice(i, j, step)
#    3220 else:
# -> 3222     idx = self._get_loc_single_level_index(level_index, key)
#    3224     if level > 0 or self._lexsort_depth == 0:
#    3225         # Desired level is not sorted
#    3226         if isinstance(idx, slice):
#    3227             # test_get_loc_partial_timestamp_multiindex
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\multi.py:2802, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2800     return -1
#    2801 else:
# -> 2802     return level_index.get_loc(key)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Store'

# %%
bwd_train.head(20)
# Out:
#                   SchoolHoliday  StateHoliday_bool  Promo
# Store Date
# 1     2013-01-01            1.0                1.0    0.0
#       2013-01-02            2.0                1.0    0.0
#       2013-01-03            3.0                1.0    0.0
#       2013-01-04            4.0                1.0    0.0
#       2013-01-05            5.0                1.0    0.0
#       2013-01-06            6.0                1.0    0.0
#       2013-01-07            7.0                1.0    1.0
#       2013-01-08            7.0                0.0    2.0
#       2013-01-09            7.0                0.0    3.0
#       2013-01-10            7.0                0.0    4.0
#       2013-01-11            7.0                0.0    5.0
#       2013-01-12            6.0                0.0    5.0
#       2013-01-13            5.0                0.0    5.0
#       2013-01-14            4.0                0.0    4.0
#       2013-01-15            3.0                0.0    3.0
#       2013-01-16            2.0                0.0    2.0
#       2013-01-17            1.0                0.0    1.0
#       2013-01-18            0.0                0.0    0.0
#       2013-01-19            0.0                0.0    0.0
#       2013-01-20            0.0                0.0    0.0

# %%
# Ordena al reves
fwd_train = df_train[['Store']+columns].sort_index(ascending=False).groupby("Store").rolling(7, min_periods=1).sum()
fwd_test = df_test[['Store']+columns].sort_index(ascending=False).groupby("Store").rolling(7, min_periods=1).sum()

# %%
fwd_train.head(20)
# Out:
#                   SchoolHoliday  StateHoliday_bool  Promo
# Store Date
# 1     2015-07-31            1.0                0.0    1.0
#       2015-07-30            2.0                0.0    2.0
#       2015-07-29            3.0                0.0    3.0
#       2015-07-28            4.0                0.0    4.0
#       2015-07-27            5.0                0.0    5.0
#       2015-07-26            5.0                0.0    5.0
#       2015-07-25            5.0                0.0    5.0
#       2015-07-24            4.0                0.0    4.0
#       2015-07-23            3.0                0.0    3.0
#       2015-07-22            2.0                0.0    2.0
#       2015-07-21            1.0                0.0    1.0
#       2015-07-20            0.0                0.0    0.0
#       2015-07-19            0.0                0.0    0.0
#       2015-07-18            0.0                0.0    0.0
#       2015-07-17            0.0                0.0    1.0
#       2015-07-16            0.0                0.0    2.0
#       2015-07-15            0.0                0.0    3.0
#       2015-07-14            0.0                0.0    4.0
#       2015-07-13            0.0                0.0    5.0
#       2015-07-12            0.0                0.0    5.0

# %%
fwd_train.drop('Store',axis=1,inplace=True)
fwd_train.reset_index(inplace=True)
fwd_test.drop('Store',axis=1,inplace=True)
fwd_test.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 fwd_train.drop(columns='Store',inplace=True)
#       2 fwd_train.reset_index(inplace=True)
#       3 fwd_test.drop('Store',axis=1,inplace=True)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\envs\cursoDL_python38\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Store'] not found in axis"

# %%
df_train.reset_index(inplace=True)
df_test.reset_index(inplace=True)

# %%
df_train = df_train.merge(bwd_train, 'left', ['Date', 'Store'], suffixes=['', '_bw'])
df_train = df_train.merge(fwd_train, 'left', ['Date', 'Store'], suffixes=['', '_fw'])
df_test = df_test.merge(bwd_test, 'left', ['Date', 'Store'], suffixes=['', '_bw'])
df_test = df_test.merge(fwd_test, 'left', ['Date', 'Store'], suffixes=['', '_fw'])

# %%
df_train.drop(columns,1,inplace=True)
df_test.drop(columns,1,inplace=True)
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_17344\1712141276.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_train.drop(columns,1,inplace=True)
# C:\Users\marco\AppData\Local\Temp\ipykernel_17344\1712141276.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_test.drop(columns,1,inplace=True)

# %%
df_train.head()
# Out:
#         Date  Store  AfterSchoolHoliday  BeforeSchoolHoliday  \
# 0 2015-07-31      1                   0                    0
# 1 2015-07-30      1                   0                    0
# 2 2015-07-29      1                   0                    0
# 3 2015-07-28      1                   0                    0
# 4 2015-07-27      1                   0                    0
#
#    AfterStateHoliday_bool  BeforeStateHoliday_bool  AfterPromo  BeforePromo  \
# 0                      57                        0           0            0
# 1                      56                        0           0            0
# 2                      55                        0           0            0
# 3                      54                        0           0            0
# 4                      53                        0           0            0
#
#    SchoolHoliday_bw  StateHoliday_bool_bw  Promo_bw  SchoolHoliday_fw  \
# 0               5.0                   0.0       5.0               1.0
# 1               4.0                   0.0       4.0               2.0
# 2               3.0                   0.0       3.0               3.0
# 3               2.0                   0.0       2.0               4.0
# 4               1.0                   0.0       1.0               5.0
#
#    StateHoliday_bool_fw  Promo_fw
# 0                   0.0       1.0
# 1                   0.0       2.0
# 2                   0.0       3.0
# 3                   0.0       4.0
# 4                   0.0       5.0

# %%
df_train["Date"] = pd.to_datetime(df_train.Date)
df_test["Date"] = pd.to_datetime(df_test.Date)

# %%
df_train.head()
# Out:
#         Date  Store  AfterSchoolHoliday  BeforeSchoolHoliday  \
# 0 2015-07-31      1                   0                    0
# 1 2015-07-30      1                   0                    0
# 2 2015-07-29      1                   0                    0
# 3 2015-07-28      1                   0                    0
# 4 2015-07-27      1                   0                    0
#
#    AfterStateHoliday_bool  BeforeStateHoliday_bool  AfterPromo  BeforePromo  \
# 0                      57                        0           0            0
# 1                      56                        0           0            0
# 2                      55                        0           0            0
# 3                      54                        0           0            0
# 4                      53                        0           0            0
#
#    SchoolHoliday_bw  StateHoliday_bool_bw  Promo_bw  SchoolHoliday_fw  \
# 0               5.0                   0.0       5.0               1.0
# 1               4.0                   0.0       4.0               2.0
# 2               3.0                   0.0       3.0               3.0
# 3               2.0                   0.0       2.0               4.0
# 4               1.0                   0.0       1.0               5.0
#
#    StateHoliday_bool_fw  Promo_fw
# 0                   0.0       1.0
# 1                   0.0       2.0
# 2                   0.0       3.0
# 3                   0.0       4.0
# 4                   0.0       5.0

# %%
plt.figure(figsize=(20,3))
df_train[df_train['Store'] == 280]['BeforeSchoolHoliday'].plot()
df_train[df_train['Store'] == 280]['BeforeStateHoliday_bool'].plot()
df_train[df_train['Store'] == 280]['BeforePromo'].plot()
plt.legend()
plt.show()

plt.figure(figsize=(20,3))
df_train[df_train['Store'] == 280]['AfterSchoolHoliday'].plot()
df_train[df_train['Store'] == 280]['AfterStateHoliday_bool'].plot()
df_train[df_train['Store'] == 280]['AfterPromo'].plot()
plt.legend()
plt.show()

# %%
def join_df(left, right, left_on, right_on=None):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, 
                      suffixes=("", "_y"))

# %%
joined_train = join_df(joined_train, df_train, ['Store', 'Date'])
joined_test = join_df(joined_test, df_test, ['Store', 'Date'])

# %%
joined_train.shape
# Out:
# (1017209, 81)

# %%
joined_train.to_feather('all_preprocessed_train.fth')

# %%
joined_test.to_feather('all_preprocessed_test.fth')

# %%
plt.figure(figsize=(20,3))
plt.plot(joined_train[joined_train['Store']==280]['StateHoliday_bool'].values[100:310]*1.0, c='b', marker='.', linestyle='None')
plt.plot(joined_train[joined_train['Store']==280]['StateHoliday_bool_bw'].values[100:310]*1.0, c='r', label='backward')
plt.plot(joined_train[joined_train['Store']==280]['StateHoliday_bool_fw'].values[100:310]*1.0, c='g', label='forward')
plt.legend()
plt.title('State Holidays')
plt.figure(figsize=(20,3))
plt.plot(joined_train[joined_train['Store']==280]['Promo'].values[100:310]*1.0, c='b', marker='.', linestyle='None')
plt.plot(joined_train[joined_train['Store']==280]['Promo_bw'].values[100:310]*1.0, c='r', label='backward')
plt.plot(joined_train[joined_train['Store']==280]['Promo_fw'].values[100:310]*1.0, c='g', label='forward')
plt.legend()
plt.title('Promo')
# Out:
# Text(0.5, 1.0, 'Promo')

# %%
joined_train
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday  Year  ...  AfterStateHoliday_bool  \
# 0                  0              1  2015  ...                      57
# 1                  0              1  2015  ...                      67
# 2                  0              1  2015  ...                      57
# 3                  0              1  2015  ...                      67
# 4                  0              1  2015  ...                      57
# ...              ...            ...   ...  ...                     ...
# 1017204            a              1  2013  ...                       0
# 1017205            a              1  2013  ...                       0
# 1017206            a              1  2013  ...                       0
# 1017207            a              1  2013  ...                       0
# 1017208            a              1  2013  ...                       0
#
#          BeforeStateHoliday_bool  AfterPromo BeforePromo SchoolHoliday_bw  \
# 0                              0           0           0              5.0
# 1                              0           0           0              5.0
# 2                              0           0           0              5.0
# 3                              0           0           0              5.0
# 4                              0           0           0              5.0
# ...                          ...         ...         ...              ...
# 1017204                        0           0          -6              1.0
# 1017205                        0           0          -6              1.0
# 1017206                        0           0          -6              1.0
# 1017207                        0           0          -6              1.0
# 1017208                        0           0          -6              1.0
#
#          StateHoliday_bool_bw  Promo_bw  SchoolHoliday_fw  \
# 0                         0.0       5.0               1.0
# 1                         0.0       5.0               1.0
# 2                         0.0       5.0               1.0
# 3                         0.0       5.0               1.0
# 4                         0.0       5.0               1.0
# ...                       ...       ...               ...
# 1017204                   1.0       0.0               4.0
# 1017205                   1.0       0.0               4.0
# 1017206                   1.0       0.0               4.0
# 1017207                   1.0       0.0               4.0
# 1017208                   1.0       0.0               7.0
#
#          StateHoliday_bool_fw  Promo_fw
# 0                         0.0       1.0
# 1                         0.0       1.0
# 2                         0.0       1.0
# 3                         0.0       1.0
# 4                         0.0       1.0
# ...                       ...       ...
# 1017204                   1.0       1.0
# 1017205                   1.0       1.0
# 1017206                   1.0       1.0
# 1017207                   1.0       1.0
# 1017208                   1.0       1.0
#
# [1017209 rows x 81 columns]
